# %% [markdown]
# # Question Zero

# %%
passwords = ["hello123", "cat", "secure2024", "password"] 
accepted = []
not_accepted =[]

for x in passwords:
    if not len(x) < 8:
        if (any(char.isdigit() for char in x)):
            accepted.append(x)
        else:
            not_accepted.append(x)
    else:
        not_accepted.append(x)
        
print(f"{accepted} accepted passwords")
print(f"{not_accepted} not accepted passwords")
# Out:
# ['hello123', 'secure2024'] accepted passwords
# ['cat', 'password'] not accepted passwords

# %%
print("Hello world")
# Out:
# Hello world
