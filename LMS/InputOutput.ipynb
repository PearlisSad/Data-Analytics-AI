# %% [markdown]
# # Input Output

# %%
file = open('lyrics.txt')
lyrics = file.read()
file.close()
print(lyrics)
# Out:
# Running cells with 'venv (Python 3.14.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/rapha/Documents/Code Institute/Data Analytics/venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
