# %% [markdown]
# # Agenda
# - Data Dictionary
# - Introduction
# - Pandas Basics

# %% [markdown]
# # Data dictionary
#
# ---
#
# ## 1) `fitness_sessions_2025.csv` &nbsp;*(752 rows × 26 cols)*
# **Grain:** one **gym session** per row.
#
# | Column | Type | Description |
# |---|---|---|
# | `session_id` | string | Short UUID for the session. |
# | `user_id` | string | Stable user key (`U001`…`U010`). |
# | `user_name` | string | Friendly name (e.g., Alice, Ben). |
# | `sex` | string | `M` / `F`. |
# | `age` | int | Age in years. |
# | `experience_level` | string | Beginner / Intermediate / Advanced. |
# | `goal` | string | Fat Loss / Muscle Gain / Endurance / Strength / Recomp / General Fitness / Performance. |
# | `city` | string | Home gym city. |
# | `join_date` | date (ISO) | Date the user “joined” the dataset. |
# | `start_datetime` | datetime (ISO) | Session start timestamp. |
# | `duration_min` | int | Session length (minutes). |
# | `workout_type` | string | Strength / Hypertrophy / Cardio / HIIT / Mobility / Mixed. |
# | `focus_muscle_group` | string | Chest / Back / Legs / Shoulders / Arms / Full Body / Core. |
# | `exercises_count` | int | Number of distinct exercises performed. |
# | `avg_heart_rate_bpm` | int | Average heart rate during the session. |
# | `max_heart_rate_bpm` | int | Peak heart rate during the session. |
# | `calories_burned` | int | Estimated kilocalories expended. |
# | `perceived_exertion_rpe` | int | Session RPE, 3–10. |
# | `equipment_availability` | string | High / Medium / Low (proxy for gym busyness). |
# | `class_attended` | bool | `True` if a class-based session. |
# | `trainer` | string or null | Trainer name if class-based. |
# | `body_weight_kg` | float | Weigh-in captured around the session (slow trend + noise). |
# | `body_fat_pct` | float | Body fat % (goal-aligned slow trend). |
# | `waist_cm` | float | Waist circumference inferred from BF trend. |
# | `resting_heart_rate_bpm` | int | User’s baseline resting HR. |
# | `notes` | string | Short human-like diary note. |
#
# ---
#
# ## 2) `fitness_daily_checkins_2025.csv` &nbsp;*(989 rows × 24 cols)*
# **Grain:** one **daily check-in per user** (≈70% coverage to mimic real life).
#
# | Column | Type | Description |
# |---|---|---|
# | `user_id` | string | Matches sessions file. |
# | `date` | date (ISO) | `date`. |
# | `city` | string | city |
# | `sleep_hours` | float | 3.0–10.5 hours. |
# | `steps` | int | 1,000–20,000 steps. |
# | `readiness_score` | int | 40–98 (overall readiness/recovery). |
# | `soreness_level` | string | None / Mild / Moderate / Severe. |
# | `mood` | string | Low / OK / Good / Great. |
# | `hydration_l` | float | Litres per day (1.2–5.0). |
# | `caffeine_mg` | int | Estimated daily caffeine intake. |
# | `creatine_g` | int | 0 or 5 (habit-ish). |
# | `calories_intake` | int | Daily kcal (goal-aligned trend + noise). |
# | `protein_g` | int | Daily protein in grams. |
# | `carbs_g` | int | Daily carbohydrate in grams. |
# | `fat_g` | int | Daily fat in grams. |
# | `resting_hr_bpm` | int | Resting heart rate (slow trend with noise). |
# | `hrv_ms` | int | Heart rate variability in ms (tends to improve with consistency). |
# | `bp_systolic` | int | Systolic BP snapshot. |
# | `bp_diastolic` | int | Diastolic BP snapshot. |
# | `body_weight_kg` | float | Daily body weight (slow trend + noise). |
# | `body_fat_pct` | float | Daily body fat %. |
# | `waist_cm` | float | Daily waist circumference. |
# | `rest_day` | bool | `True` if rest day. |
# | `injury_note` | string or null | Occasional niggle note (e.g., “Knee niggle”). |

# %% [markdown]
# # Introduction
# Pandas is a third party library in Python. It is designed for data analysis and manipulation. It is built on top of Numpy to handle numerical analysis and integrated with seaborn and matplotlib for Plotting.

# %%
import pandas as pd

# %%
sessions_df = pd.read_csv("fitness_sessions_2025.csv")
daily_checkins_df = pd.read_csv("fitness_daily_checkins_2025.csv")

# %%
sessions_df.head(2)
# Out:
#   session_id user_id user_name sex  age experience_level      goal    city  \
# 0   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss  London
# 1   0b89057a    U001     Alice   F   29     Intermediate  Fat Loss  London
#
#     join_date       start_datetime  ...  calories_burned  \
# 0  2025-06-14  2025-06-16T07:45:00  ...              507
# 1  2025-06-14  2025-06-17T19:30:00  ...              457
#
#   perceived_exertion_rpe equipment_availability  class_attended  trainer  \
# 0                      7                   High           False      NaN
# 1                      5                   High           False      NaN
#
#    body_weight_kg  body_fat_pct  waist_cm resting_heart_rate_bpm  \
# 0            77.6          31.1      93.2                     58
# 1            77.2          30.8      92.6                     58
#
#                   notes
# 0        Tight on time.
# 1  Used lifting straps.
#
# [2 rows x 26 columns]

# %%
sessions_df.tail(2)
# Out:
#     session_id user_id user_name sex  age experience_level       goal  \
# 750   07f47956    U010      Jude   M   31     Intermediate  Endurance
# 751   a63febae    U010      Jude   M   31     Intermediate  Endurance
#
#         city   join_date       start_datetime  ...  calories_burned  \
# 750  Glasgow  2025-06-18  2025-10-25T07:45:00  ...              580
# 751  Glasgow  2025-06-18  2025-10-26T18:30:00  ...              477
#
#     perceived_exertion_rpe equipment_availability  class_attended  trainer  \
# 750                      8                   High           False      NaN
# 751                      6                   High           False      NaN
#
#      body_weight_kg  body_fat_pct  waist_cm resting_heart_rate_bpm  \
# 750            72.1          17.5      83.6                     57
# 751            72.2          16.7      83.9                     57
#
#                 notes
# 750  Good pump today.
# 751  Focused on form.
#
# [2 rows x 26 columns]

# %%
sessions_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 752 entries, 0 to 751
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   session_id              752 non-null    object
#  1   user_id                 752 non-null    object
#  2   user_name               752 non-null    object
#  3   sex                     752 non-null    object
#  4   age                     752 non-null    int64
#  5   experience_level        752 non-null    object
#  6   goal                    752 non-null    object
#  7   city                    752 non-null    object
#  8   join_date               752 non-null    object
#  9   start_datetime          752 non-null    object
#  10  duration_min            752 non-null    int64
#  11  workout_type            752 non-null    object
#  12  focus_muscle_group      752 non-null    object
#  13  exercises_count         752 non-null    int64
# ...

# %%
daily_checkins_df.head(2)
# Out:
#   user_id        date    city  sleep_hours  steps  readiness_score  \
# 0    U001  2025-06-16  London          7.6   8996               76
# 1    U001  2025-06-18  London          5.9   5594               66
#
#   soreness_level   mood  hydration_l  caffeine_mg  ...  fat_g  resting_hr_bpm  \
# 0       Moderate     OK         3.50          161  ...     84              59
# 1            NaN  Great         2.93          207  ...     82              56
#
#    hrv_ms  bp_systolic  bp_diastolic  body_weight_kg  body_fat_pct  waist_cm  \
# 0      27          133            74            77.3          30.9      91.3
# 1      42          115            71            77.4          31.1      92.9
#
#    rest_day  injury_note
# 0      True          NaN
# 1     False          NaN
#
# [2 rows x 24 columns]

# %%
daily_checkins_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 989 entries, 0 to 988
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   user_id          989 non-null    object
#  1   date             989 non-null    object
#  2   city             989 non-null    object
#  3   sleep_hours      989 non-null    float64
#  4   steps            989 non-null    int64
#  5   readiness_score  989 non-null    int64
#  6   soreness_level   730 non-null    object
#  7   mood             989 non-null    object
#  8   hydration_l      989 non-null    float64
#  9   caffeine_mg      989 non-null    int64
#  10  creatine_g       989 non-null    int64
#  11  calories_intake  989 non-null    int64
#  12  protein_g        989 non-null    int64
#  13  carbs_g          989 non-null    int64
#  14  fat_g            989 non-null    int64
#  15  resting_hr_bpm   989 non-null    int64
#  16  hrv_ms           989 non-null    int64
# ...

# %%
sessions_df.describe()
# Out:
#               age  duration_min  exercises_count  avg_heart_rate_bpm  \
# count  752.000000    752.000000       752.000000          752.000000
# mean    33.892287     57.139628         6.448138          103.327128
# std      6.281912     21.544626         2.976601           11.634327
# min     23.000000     19.000000         1.000000           67.000000
# 25%     29.000000     36.000000         5.000000           96.000000
# 50%     34.000000     63.000000         7.000000          103.000000
# 75%     39.000000     76.000000         9.000000          112.000000
# max     45.000000     97.000000        12.000000          137.000000
#
#        max_heart_rate_bpm  calories_burned  perceived_exertion_rpe  \
# count          752.000000       752.000000              752.000000
# mean           132.997340       443.234043                6.268617
# std             14.055909       157.840726                1.556627
# min             82.000000        86.000000                3.000000
# ...

# %%
daily_checkins_df.describe()
# Out:
#        sleep_hours         steps  readiness_score  hydration_l  caffeine_mg  \
# count   989.000000    989.000000       989.000000   989.000000   989.000000
# mean      6.952983   8586.139535        74.033367     2.603913   187.446916
# std       1.170281   2844.682834        12.003116     0.762789   115.632395
# min       3.400000   1000.000000        40.000000     1.200000     0.000000
# 25%       6.200000   6680.000000        66.000000     2.050000   100.000000
# 50%       6.900000   8624.000000        74.000000     2.590000   182.000000
# 75%       7.700000  10443.000000        83.000000     3.140000   259.000000
# max      10.500000  16696.000000        98.000000     5.000000   575.000000
#
#        creatine_g  calories_intake   protein_g     carbs_g       fat_g  \
# count  989.000000       989.000000  989.000000  989.000000  989.000000
# mean     2.699697      2220.631951  144.826087  244.406471   73.600607
# ...

# %%
# pandas series
sessions_df["user_id"]
# Out:
# 0      U001
# 1      U001
# 2      U001
# 3      U001
# 4      U001
#        ...
# 747    U010
# 748    U010
# 749    U010
# 750    U010
# 751    U010
# Name: user_id, Length: 752, dtype: object

# %% [markdown]
# ### 1. How many users were involved in this experiment?
# 10 users in total were involved in this experiment. Users were given an ID U001...U010

# %%
# 10 users particpated in this analysis
sessions_df["user_id"].nunique()
# Out:
# 10

# %%
daily_checkins_df["user_id"].nunique()
# Out:
# 10

# %%
sessions_df["user_id"].value_counts()
# Out:
# user_id
# U003    102
# U008     84
# U006     82
# U001     79
# U010     79
# U005     75
# U009     67
# U002     65
# U004     64
# U007     55
# Name: count, dtype: int64

# %%
daily_checkins_df["user_id"].value_counts()
# Out:
# user_id
# U004    109
# U005    107
# U002    105
# U006    103
# U009    102
# U003    101
# U008     96
# U001     94
# U007     88
# U010     84
# Name: count, dtype: int64

# %%
sessions_df["user_id"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='user_id'>

# %%
sessions_df["sex"].value_counts()
# Out:
# sex
# F    378
# M    374
# Name: count, dtype: int64

# %%
sessions_df.head(1)
# Out:
#   session_id user_id user_name sex  age experience_level      goal    city  \
# 0   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss  London
#
#     join_date       start_datetime  ...  calories_burned  \
# 0  2025-06-14  2025-06-16T07:45:00  ...              507
#
#   perceived_exertion_rpe equipment_availability  class_attended  trainer  \
# 0                      7                   High           False      NaN
#
#    body_weight_kg  body_fat_pct  waist_cm resting_heart_rate_bpm  \
# 0            77.6          31.1      93.2                     58
#
#             notes
# 0  Tight on time.
#
# [1 rows x 26 columns]

# %%
sessions_df["start_datetime"]
# Out:
# 0      2025-06-16T07:45:00
# 1      2025-06-17T19:30:00
# 2      2025-06-18T19:10:00
# 3      2025-06-19T17:15:00
# 4      2025-06-21T18:20:00
#               ...
# 747    2025-10-22T19:05:00
# 748    2025-10-23T12:05:00
# 749    2025-10-24T07:45:00
# 750    2025-10-25T07:45:00
# 751    2025-10-26T18:30:00
# Name: start_datetime, Length: 752, dtype: object

# %%
sessions_df["start_datetime"] = pd.to_datetime(sessions_df["start_datetime"])

# %%
sessions_df["start_datetime"]
# Out:
# 0     2025-06-16 07:45:00
# 1     2025-06-17 19:30:00
# 2     2025-06-18 19:10:00
# 3     2025-06-19 17:15:00
# 4     2025-06-21 18:20:00
#               ...
# 747   2025-10-22 19:05:00
# 748   2025-10-23 12:05:00
# 749   2025-10-24 07:45:00
# 750   2025-10-25 07:45:00
# 751   2025-10-26 18:30:00
# Name: start_datetime, Length: 752, dtype: datetime64[ns]

# %%
sessions_df["start_datetime"] = sessions_df["start_datetime"].dt.normalize()

# %%
sessions_df["start_datetime"]
# Out:
# 0     2025-06-16
# 1     2025-06-17
# 2     2025-06-18
# 3     2025-06-19
# 4     2025-06-21
#          ...
# 747   2025-10-22
# 748   2025-10-23
# 749   2025-10-24
# 750   2025-10-25
# 751   2025-10-26
# Name: start_datetime, Length: 752, dtype: datetime64[ns]

# %%
daily_checkins_df["date"]
# Out:
# 0      2025-06-16
# 1      2025-06-18
# 2      2025-06-20
# 3      2025-06-21
# 4      2025-06-22
#           ...
# 984    2025-10-21
# 985    2025-10-22
# 986    2025-10-23
# 987    2025-10-24
# 988    2025-10-25
# Name: date, Length: 989, dtype: object

# %%
daily_checkins_df["date"] = pd.to_datetime(daily_checkins_df["date"])

# %%
daily_checkins_df["date"]
# Out:
# 0     2025-06-16
# 1     2025-06-18
# 2     2025-06-20
# 3     2025-06-21
# 4     2025-06-22
#          ...
# 984   2025-10-21
# 985   2025-10-22
# 986   2025-10-23
# 987   2025-10-24
# 988   2025-10-25
# Name: date, Length: 989, dtype: datetime64[ns]

# %%
daily_checkins_df["date"].dt.year
# Out:
# 0      2025
# 1      2025
# 2      2025
# 3      2025
# 4      2025
#        ...
# 984    2025
# 985    2025
# 986    2025
# 987    2025
# 988    2025
# Name: date, Length: 989, dtype: int32

# %%
daily_checkins_df["date"].dt.month
print(daily_checkins_df.dtypes)
# Out:
# user_id                    object
# date               datetime64[ns]
# city                       object
# sleep_hours               float64
# steps                       int64
# readiness_score             int64
# soreness_level             object
# mood                       object
# hydration_l               float64
# caffeine_mg                 int64
# creatine_g                  int64
# calories_intake             int64
# protein_g                   int64
# carbs_g                     int64
# fat_g                       int64
# resting_hr_bpm              int64
# hrv_ms                      int64
# bp_systolic                 int64
# bp_diastolic                int64
# body_weight_kg            float64
# body_fat_pct              float64
# waist_cm                  float64
# rest_day                     bool
# injury_note                object
# dtype: object

# %%
# sessions_df.rename(columns={"start_datetime": "date"}, inplace=True)
# sessions_df = sessions_df.rename(columns={"start_datetime": "date"})

# %%
df = pd.merge(sessions_df, daily_checkins_df, 
         left_on=["user_id", "city", "start_datetime"],
         right_on= ["user_id", "city", "date"],
         suffixes = ("_sessions", "_checkins")
        )

# %%
df.shape
# Out:
# (538, 48)

# %%
df.head(2)
# Out:
#   session_id user_id user_name sex  age experience_level      goal    city  \
# 0   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss  London
# 1   2401871e    U001     Alice   F   29     Intermediate  Fat Loss  London
#
#     join_date start_datetime  ...  fat_g resting_hr_bpm hrv_ms  bp_systolic  \
# 0  2025-06-14     2025-06-16  ...     84             59     27          133
# 1  2025-06-14     2025-06-18  ...     82             56     42          115
#
#    bp_diastolic  body_weight_kg_checkins  body_fat_pct_checkins  \
# 0            74                     77.3                   30.9
# 1            71                     77.4                   31.1
#
#    waist_cm_checkins rest_day  injury_note
# 0               91.3     True          NaN
# 1               92.9    False          NaN
#
# [2 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['session_id', 'user_id', 'user_name', 'sex', 'age', 'experience_level',
#        'goal', 'city', 'join_date', 'start_datetime', 'duration_min',
#        'workout_type', 'focus_muscle_group', 'exercises_count',
#        'avg_heart_rate_bpm', 'max_heart_rate_bpm', 'calories_burned',
#        'perceived_exertion_rpe', 'equipment_availability', 'class_attended',
#        'trainer', 'body_weight_kg_sessions', 'body_fat_pct_sessions',
#        'waist_cm_sessions', 'resting_heart_rate_bpm', 'notes', 'date',
#        'sleep_hours', 'steps', 'readiness_score', 'soreness_level', 'mood',
#        'hydration_l', 'caffeine_mg', 'creatine_g', 'calories_intake',
#        'protein_g', 'carbs_g', 'fat_g', 'resting_hr_bpm', 'hrv_ms',
#        'bp_systolic', 'bp_diastolic', 'body_weight_kg_checkins',
#        'body_fat_pct_checkins', 'waist_cm_checkins', 'rest_day',
#        'injury_note'],
#       dtype='object')

# %%
# selections of dataframes
# loc for names
# iloc for postions

# %%
# df.loc[rows, cols]
df.loc[[5,7,10], ["user_name", "start_datetime", "date"]]
# Out:
#    user_name start_datetime       date
# 5      Alice     2025-07-02 2025-07-02
# 7      Alice     2025-07-05 2025-07-05
# 10     Alice     2025-07-13 2025-07-13

# %%
df.loc[:, ["user_name", "start_datetime", "date"]]
# Out:
#     user_name start_datetime       date
# 0       Alice     2025-06-16 2025-06-16
# 1       Alice     2025-06-18 2025-06-18
# 2       Alice     2025-06-21 2025-06-21
# 3       Alice     2025-06-29 2025-06-29
# 4       Alice     2025-07-01 2025-07-01
# ..        ...            ...        ...
# 533      Jude     2025-10-21 2025-10-21
# 534      Jude     2025-10-22 2025-10-22
# 535      Jude     2025-10-23 2025-10-23
# 536      Jude     2025-10-24 2025-10-24
# 537      Jude     2025-10-25 2025-10-25
#
# [538 rows x 3 columns]

# %%
df.iloc[[5,7,10], [2, 9, 26]]
# Out:
#    user_name start_datetime       date
# 5      Alice     2025-07-02 2025-07-02
# 7      Alice     2025-07-05 2025-07-05
# 10     Alice     2025-07-13 2025-07-13

# %%
df.set_index("date", inplace=True)

# %%
df.head()
# Out:
#            session_id user_id user_name sex  age experience_level      goal  \
# date
# 2025-06-16   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-18   2401871e    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-21   fa5cd177    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-29   d4649d05    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-07-01   c41363d9    U001     Alice   F   29     Intermediate  Fat Loss
#
#               city   join_date start_datetime  ...  fat_g resting_hr_bpm  \
# date                                           ...
# 2025-06-16  London  2025-06-14     2025-06-16  ...     84             59
# 2025-06-18  London  2025-06-14     2025-06-18  ...     82             56
# 2025-06-21  London  2025-06-14     2025-06-21  ...     65             57
# 2025-06-29  London  2025-06-14     2025-06-29  ...     59             56
# 2025-07-01  London  2025-06-14     2025-07-01  ...     63             55
#
# ...

# %%
df.query("goal=='Fat Loss'")
# Out:
#            session_id user_id user_name sex  age experience_level      goal  \
# date
# 2025-06-16   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-18   2401871e    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-21   fa5cd177    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-29   d4649d05    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-07-01   c41363d9    U001     Alice   F   29     Intermediate  Fat Loss
# ...               ...     ...       ...  ..  ...              ...       ...
# 2025-10-11   7a239d6e    U005      Ella   F   37         Beginner  Fat Loss
# 2025-10-12   a3418fdc    U005      Ella   F   37         Beginner  Fat Loss
# 2025-10-14   1e5fedc8    U005      Ella   F   37         Beginner  Fat Loss
# 2025-10-16   12d851d2    U005      Ella   F   37         Beginner  Fat Loss
# 2025-10-19   d8ad6fd2    U005      Ella   F   37         Beginner  Fat Loss
#
# ...

# %%
df.query("age>32 and goal=='Fat Loss'")
# Out:
#            session_id user_id user_name sex  age experience_level      goal  \
# date
# 2025-06-07   00d4a330    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-08   54b8eff2    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-09   0aa3413a    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-10   cc266379    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-11   d3d83124    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-14   e319c14b    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-15   bf260d8f    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-16   3c0558ef    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-18   d97d6c7d    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-20   a511883d    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-24   6c713a06    U005      Ella   F   37         Beginner  Fat Loss
# ...

# %%
exp = (df["age"] > 32) & (df["goal"] == "Fat Loss")

# %%
df[exp]
# Out:
#            session_id user_id user_name sex  age experience_level      goal  \
# date
# 2025-06-07   00d4a330    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-08   54b8eff2    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-09   0aa3413a    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-10   cc266379    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-11   d3d83124    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-14   e319c14b    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-15   bf260d8f    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-16   3c0558ef    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-18   d97d6c7d    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-20   a511883d    U005      Ella   F   37         Beginner  Fat Loss
# 2025-06-24   6c713a06    U005      Ella   F   37         Beginner  Fat Loss
# ...

# %%
ella_df = df.query("user_name == 'Ella'")

# %%
ella_df["body_weight_kg_sessions"].plot(kind="line")
# Out:
# <Axes: xlabel='date'>

# %%
clara = df.query("goal=='Muscle Gain' and user_name=='Clara'")

# %%
clara["body_weight_kg_sessions"].plot(kind="line")
# Out:
# <Axes: xlabel='date'>

# %% [markdown]
# ## Time Series with Panda

# %%
df.head()
# Out:
#            session_id user_id user_name sex  age experience_level      goal  \
# date
# 2025-06-16   455bd1f7    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-18   2401871e    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-21   fa5cd177    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-06-29   d4649d05    U001     Alice   F   29     Intermediate  Fat Loss
# 2025-07-01   c41363d9    U001     Alice   F   29     Intermediate  Fat Loss
#
#               city   join_date start_datetime  ...  fat_g resting_hr_bpm  \
# date                                           ...
# 2025-06-16  London  2025-06-14     2025-06-16  ...     84             59
# 2025-06-18  London  2025-06-14     2025-06-18  ...     82             56
# 2025-06-21  London  2025-06-14     2025-06-21  ...     65             57
# 2025-06-29  London  2025-06-14     2025-06-29  ...     59             56
# 2025-07-01  London  2025-06-14     2025-07-01  ...     63             55
#
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2025-06-16', '2025-06-18', '2025-06-21', '2025-06-29',
#                '2025-07-01', '2025-07-02', '2025-07-04', '2025-07-05',
#                '2025-07-07', '2025-07-09',
#                ...
#                '2025-10-04', '2025-10-05', '2025-10-06', '2025-10-10',
#                '2025-10-18', '2025-10-21', '2025-10-22', '2025-10-23',
#                '2025-10-24', '2025-10-25'],
#               dtype='datetime64[ns]', name='date', length=538, freq=None)

# %%
df.columns
# Out:
# Index(['session_id', 'user_id', 'user_name', 'sex', 'age', 'experience_level',
#        'goal', 'city', 'join_date', 'start_datetime', 'duration_min',
#        'workout_type', 'focus_muscle_group', 'exercises_count',
#        'avg_heart_rate_bpm', 'max_heart_rate_bpm', 'calories_burned',
#        'perceived_exertion_rpe', 'equipment_availability', 'class_attended',
#        'trainer', 'body_weight_kg_sessions', 'body_fat_pct_sessions',
#        'waist_cm_sessions', 'resting_heart_rate_bpm', 'notes', 'sleep_hours',
#        'steps', 'readiness_score', 'soreness_level', 'mood', 'hydration_l',
#        'caffeine_mg', 'creatine_g', 'calories_intake', 'protein_g', 'carbs_g',
#        'fat_g', 'resting_hr_bpm', 'hrv_ms', 'bp_systolic', 'bp_diastolic',
#        'body_weight_kg_checkins', 'body_fat_pct_checkins', 'waist_cm_checkins',
#        'rest_day', 'injury_note'],
#       dtype='object')

# %%
# first thing to do when dealing with a time series data ie when datetime is the index
# sort the index
df.sort_index()
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-02   830afe5c    U009       Ivy   F   23         Beginner
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
# 2025-06-03   4be34580    U004       Dan   M   26     Intermediate
# 2025-06-03   3666a391    U009       Ivy   F   23         Beginner
# 2025-06-03   e98dfa7f    U002       Ben   M   34         Beginner
# ...               ...     ...       ...  ..  ...              ...
# 2025-10-24   d9cf6ec2    U010      Jude   M   31     Intermediate
# 2025-10-25   fb926ce7    U001     Alice   F   29     Intermediate
# 2025-10-25   3adea31e    U006      Femi   M   32     Intermediate
# 2025-10-25   07f47956    U010      Jude   M   31     Intermediate
# 2025-10-26   234df117    U001     Alice   F   29     Intermediate
#
#                        goal        city   join_date start_datetime  ...  \
# date                                                                ...
# ...

# %%
df.sort_index(inplace=True)

# %%
df.head()
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-02   830afe5c    U009       Ivy   F   23         Beginner
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
# 2025-06-03   4be34580    U004       Dan   M   26     Intermediate
# 2025-06-03   3666a391    U009       Ivy   F   23         Beginner
# 2025-06-03   e98dfa7f    U002       Ben   M   34         Beginner
#
#                        goal        city   join_date start_datetime  ...  \
# date                                                                ...
# 2025-06-02  General Fitness      London  2025-06-01     2025-06-02  ...
# 2025-06-03      Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...
# 2025-06-03      Performance  Manchester  2025-06-03     2025-06-03  ...
# 2025-06-03  General Fitness      London  2025-06-01     2025-06-03  ...
# 2025-06-03  General Fitness      London  2025-06-02     2025-06-03  ...
#
# ...

# %%
df.loc["2025-06": "2025-08"] # june to Aug
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-02   830afe5c    U009       Ivy   F   23         Beginner
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
# 2025-06-03   4be34580    U004       Dan   M   26     Intermediate
# 2025-06-03   3666a391    U009       Ivy   F   23         Beginner
# 2025-06-03   e98dfa7f    U002       Ben   M   34         Beginner
# ...               ...     ...       ...  ..  ...              ...
# 2025-08-31   2cc5e799    U008    Hassan   M   39         Advanced
# 2025-08-31   1e7b50ad    U001     Alice   F   29     Intermediate
# 2025-08-31   4fd19d01    U002       Ben   M   34         Beginner
# 2025-08-31   44d2ab1a    U003     Clara   F   41         Advanced
# 2025-08-31   efda093d    U004       Dan   M   26     Intermediate
#
#                        goal        city   join_date start_datetime  ...  \
# date                                                                ...
# ...

# %%
df.loc["2025-08-21": "2025-09-20"]
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-08-21   35b6fc07    U001     Alice   F   29     Intermediate
# 2025-08-21   8ea3bf11    U003     Clara   F   41         Advanced
# 2025-08-21   0ff1b8bd    U008    Hassan   M   39         Advanced
# 2025-08-21   89415b2d    U004       Dan   M   26     Intermediate
# 2025-08-22   9b0d9688    U009       Ivy   F   23         Beginner
# ...               ...     ...       ...  ..  ...              ...
# 2025-09-18   b7f82f42    U003     Clara   F   41         Advanced
# 2025-09-19   3813a0e8    U004       Dan   M   26     Intermediate
# 2025-09-19   92353e21    U010      Jude   M   31     Intermediate
# 2025-09-19   0f8f7e9c    U003     Clara   F   41         Advanced
# 2025-09-19   6458d990    U001     Alice   F   29     Intermediate
#
#                        goal        city   join_date start_datetime  ...  \
# date                                                                ...
# ...

# %%
df["day_name"] = df.index.day_name()

# %%
df.head(2)
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-02   830afe5c    U009       Ivy   F   23         Beginner
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
#
#                        goal        city   join_date start_datetime  ...  \
# date                                                                ...
# 2025-06-02  General Fitness      London  2025-06-01     2025-06-02  ...
# 2025-06-03      Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...
#
#             resting_hr_bpm hrv_ms bp_systolic  bp_diastolic  \
# date
# 2025-06-02              51     36         131            85
# 2025-06-03              68     41         107            77
#
#             body_weight_kg_checkins  body_fat_pct_checkins  waist_cm_checkins  \
# date
# 2025-06-02                     64.0                   27.4               92.2
# 2025-06-03                     60.9                   19.7               83.6
#
# ...

# %% [markdown]
# ### Q2. What are the top 3 users that trained the most
# The top users are: Clara, Hassan and Femi

# %%
df["user_name"].value_counts()[:3] # top users
# Out:
# user_name
# Clara     71
# Hassan    63
# Femi      61
# Name: count, dtype: int64

# %% [markdown]
# ### Q3. What is clara goals
# Clara major goal is Muscle Gain

# %%
clara_df = df.query("user_name=='Clara'")
clara_df.head(1)
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
#
#                    goal        city   join_date start_datetime  ...  \
# date                                                            ...
# 2025-06-03  Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...
#
#             resting_hr_bpm hrv_ms bp_systolic  bp_diastolic  \
# date
# 2025-06-03              68     41         107            77
#
#             body_weight_kg_checkins  body_fat_pct_checkins  waist_cm_checkins  \
# date
# 2025-06-03                     60.9                   19.7               83.6
#
#             rest_day injury_note  day_name
# date
# 2025-06-03     False         NaN   Tuesday
#
# [1 rows x 48 columns]

# %%
# confirm Clara has one goal
clara_df["goal"].value_counts()
# Out:
# goal
# Muscle Gain    71
# Name: count, dtype: int64

# %%
clara_df["goal"].iloc[0]
# Out:
# 'Muscle Gain'

# %% [markdown]
# ### Q4. What does Clara sleep hours look like
# Clara is a female, she is 41 years old. She is quite an Advanced and she lives in Birmingham.

# %%
clara_df.head()
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
# 2025-06-04   022f2c5b    U003     Clara   F   41         Advanced
# 2025-06-05   60afe487    U003     Clara   F   41         Advanced
# 2025-06-06   b99eb3f7    U003     Clara   F   41         Advanced
# 2025-06-08   ebf7e220    U003     Clara   F   41         Advanced
#
#                    goal        city   join_date start_datetime  ...  \
# date                                                            ...
# 2025-06-03  Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...
# 2025-06-04  Muscle Gain  Birmingham  2025-06-01     2025-06-04  ...
# 2025-06-05  Muscle Gain  Birmingham  2025-06-01     2025-06-05  ...
# 2025-06-06  Muscle Gain  Birmingham  2025-06-01     2025-06-06  ...
# 2025-06-08  Muscle Gain  Birmingham  2025-06-01     2025-06-08  ...
#
#             resting_hr_bpm hrv_ms bp_systolic  bp_diastolic  \
# date
# ...

# %%
clara_df.columns
# Out:
# Index(['session_id', 'user_id', 'user_name', 'sex', 'age', 'experience_level',
#        'goal', 'city', 'join_date', 'start_datetime', 'duration_min',
#        'workout_type', 'focus_muscle_group', 'exercises_count',
#        'avg_heart_rate_bpm', 'max_heart_rate_bpm', 'calories_burned',
#        'perceived_exertion_rpe', 'equipment_availability', 'class_attended',
#        'trainer', 'body_weight_kg_sessions', 'body_fat_pct_sessions',
#        'waist_cm_sessions', 'resting_heart_rate_bpm', 'notes', 'sleep_hours',
#        'steps', 'readiness_score', 'soreness_level', 'mood', 'hydration_l',
#        'caffeine_mg', 'creatine_g', 'calories_intake', 'protein_g', 'carbs_g',
#        'fat_g', 'resting_hr_bpm', 'hrv_ms', 'bp_systolic', 'bp_diastolic',
#        'body_weight_kg_checkins', 'body_fat_pct_checkins', 'waist_cm_checkins',
#        'rest_day', 'injury_note', 'day_name'],
#       dtype='object')

# %%
clara_df["sleep_hours"]
# Out:
# date
# 2025-06-03    7.5
# 2025-06-04    6.4
# 2025-06-05    6.9
# 2025-06-06    7.2
# 2025-06-08    7.4
#              ...
# 2025-10-10    6.2
# 2025-10-11    7.7
# 2025-10-12    6.7
# 2025-10-18    5.6
# 2025-10-23    6.8
# Name: sleep_hours, Length: 71, dtype: float64

# %%
clara_df["sleep_hours"].describe()
# Out:
# count    71.000000
# mean      6.874648
# std       1.206852
# min       4.600000
# 25%       5.800000
# 50%       6.800000
# 75%       7.750000
# max       9.600000
# Name: sleep_hours, dtype: float64

# %%
clara_df["sleep_hours"].plot(kind="line")
# Out:
# <Axes: xlabel='date'>

# %%
clara_df["sleep_hours"].plot(kind="box")
# Out:
# <Axes: >

# %%
clara_df.resample("M")["sleep_hours"].mean()
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_29544\2630640248.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   clara_df.resample("M")["sleep_hours"].mean()
# date
# 2025-06-30    7.250000
# 2025-07-31    6.847059
# 2025-08-31    7.250000
# 2025-09-30    6.400000
# 2025-10-31    6.262500
# Freq: ME, Name: sleep_hours, dtype: float64

# %% [markdown]
# ### Q5. Does the sleep hours affect the goal

# %%
clara_df["soreness_level"]
# Out:
# date
# 2025-06-03         NaN
# 2025-06-04        Mild
# 2025-06-05         NaN
# 2025-06-06        Mild
# 2025-06-08      Severe
#                 ...
# 2025-10-10    Moderate
# 2025-10-11         NaN
# 2025-10-12         NaN
# 2025-10-18        Mild
# 2025-10-23      Severe
# Name: soreness_level, Length: 71, dtype: object

# %%
clara_df["soreness_level"].unique()
# Out:
# array([nan, 'Mild', 'Severe', 'Moderate'], dtype=object)

# %%
clara_df["soreness_level"].value_counts(dropna=False)
# Out:
# soreness_level
# Mild        34
# NaN         19
# Moderate    11
# Severe       7
# Name: count, dtype: int64

# %%
clara_df.query("soreness_level=='Severe'")[["soreness_level", "sleep_hours"]]
# Out:
#            soreness_level  sleep_hours
# date
# 2025-06-08         Severe          7.4
# 2025-07-19         Severe          7.9
# 2025-08-06         Severe          6.9
# 2025-08-15         Severe          8.0
# 2025-08-21         Severe          7.5
# 2025-09-09         Severe          5.8
# 2025-10-23         Severe          6.8

# %%
clara_df.head()
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
# 2025-06-04   022f2c5b    U003     Clara   F   41         Advanced
# 2025-06-05   60afe487    U003     Clara   F   41         Advanced
# 2025-06-06   b99eb3f7    U003     Clara   F   41         Advanced
# 2025-06-08   ebf7e220    U003     Clara   F   41         Advanced
#
#                    goal        city   join_date start_datetime  ...  \
# date                                                            ...
# 2025-06-03  Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...
# 2025-06-04  Muscle Gain  Birmingham  2025-06-01     2025-06-04  ...
# 2025-06-05  Muscle Gain  Birmingham  2025-06-01     2025-06-05  ...
# 2025-06-06  Muscle Gain  Birmingham  2025-06-01     2025-06-06  ...
# 2025-06-08  Muscle Gain  Birmingham  2025-06-01     2025-06-08  ...
#
#             resting_hr_bpm hrv_ms bp_systolic  bp_diastolic  \
# date
# ...

# %%
clara_df.shift(1)
# Out:
#            session_id user_id user_name   sex   age experience_level  \
# date
# 2025-06-03       None    None      None  None   NaN             None
# 2025-06-04   d7207938    U003     Clara     F  41.0         Advanced
# 2025-06-05   022f2c5b    U003     Clara     F  41.0         Advanced
# 2025-06-06   60afe487    U003     Clara     F  41.0         Advanced
# 2025-06-08   b99eb3f7    U003     Clara     F  41.0         Advanced
# ...               ...     ...       ...   ...   ...              ...
# 2025-10-10   4b80b17a    U003     Clara     F  41.0         Advanced
# 2025-10-11   3e3edb39    U003     Clara     F  41.0         Advanced
# 2025-10-12   1e8d1523    U003     Clara     F  41.0         Advanced
# 2025-10-18   64addf6c    U003     Clara     F  41.0         Advanced
# 2025-10-23   b1c427db    U003     Clara     F  41.0         Advanced
#
#                    goal        city   join_date start_datetime  ...  \
# ...

# %%
clara_df["sleep_day_before"] = clara_df["sleep_hours"].shift(1)
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_29544\706288830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clara_df["sleep_day_before"] = clara_df["sleep_hours"].shift(1)

# %%
clara_df.query("soreness_level=='Severe'")[["soreness_level", "sleep_hours", "sleep_day_before"]]
# Out:
#            soreness_level  sleep_hours  sleep_day_before
# date
# 2025-06-08         Severe          7.4               7.2
# 2025-07-19         Severe          7.9               7.0
# 2025-08-06         Severe          6.9               5.7
# 2025-08-15         Severe          8.0               6.0
# 2025-08-21         Severe          7.5               5.0
# 2025-09-09         Severe          5.8               6.3
# 2025-10-23         Severe          6.8               5.6

# %%
clara_df.head(1)
# Out:
#            session_id user_id user_name sex  age experience_level  \
# date
# 2025-06-03   d7207938    U003     Clara   F   41         Advanced
#
#                    goal        city   join_date start_datetime  ...  hrv_ms  \
# date                                                            ...
# 2025-06-03  Muscle Gain  Birmingham  2025-06-01     2025-06-03  ...      41
#
#            bp_systolic bp_diastolic  body_weight_kg_checkins  \
# date
# 2025-06-03         107           77                     60.9
#
#             body_fat_pct_checkins  waist_cm_checkins  rest_day  injury_note  \
# date
# 2025-06-03                   19.7               83.6     False          NaN
#
#            day_name  sleep_day_before
# date
# 2025-06-03  Tuesday               NaN
#
# [1 rows x 49 columns]

# %%
# int('22b'), int('bb')

# %%
# None / Mild / Moderate / Severe.

# %%
pd.to_numeric(clara_df["soreness_level"], errors="coerce")
# Out:
# date
# 2025-06-03   NaN
# 2025-06-04   NaN
# 2025-06-05   NaN
# 2025-06-06   NaN
# 2025-06-08   NaN
#               ..
# 2025-10-10   NaN
# 2025-10-11   NaN
# 2025-10-12   NaN
# 2025-10-18   NaN
# 2025-10-23   NaN
# Name: soreness_level, Length: 71, dtype: float64

# %%
clara_df["soreness_level"].astype('category')
# Out:
# date
# 2025-06-03         NaN
# 2025-06-04        Mild
# 2025-06-05         NaN
# 2025-06-06        Mild
# 2025-06-08      Severe
#                 ...
# 2025-10-10    Moderate
# 2025-10-11         NaN
# 2025-10-12         NaN
# 2025-10-18        Mild
# 2025-10-23      Severe
# Name: soreness_level, Length: 71, dtype: category
# Categories (3, object): ['Mild', 'Moderate', 'Severe']

# %%
mapping = {
    "Mild": 1,
    "Moderate": 2,
    "Severe": 3,
}

# %%
clara_df["soreness_level"] = clara_df["soreness_level"].replace(mapping).fillna(0)
# Out:
# C:\Users\rapha\AppData\Local\Temp\ipykernel_29544\3634953221.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   clara_df["soreness_level"] = clara_df["soreness_level"].replace(mapping).fillna(0)
# C:\Users\rapha\AppData\Local\Temp\ipykernel_29544\3634953221.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clara_df["soreness_level"] = clara_df["soreness_level"].replace(mapping).fillna(0)

# %%
clara_df["soreness_level"]
# Out:
# date
# 2025-06-03    0.0
# 2025-06-04    1.0
# 2025-06-05    0.0
# 2025-06-06    1.0
# 2025-06-08    3.0
#              ...
# 2025-10-10    2.0
# 2025-10-11    0.0
# 2025-10-12    0.0
# 2025-10-18    1.0
# 2025-10-23    3.0
# Name: soreness_level, Length: 71, dtype: float64

# %%
clara_df[["soreness_level", "sleep_day_before"]].corr(method='spearman')
# Out:
#                   soreness_level  sleep_day_before
# soreness_level          1.000000         -0.046153
# sleep_day_before       -0.046153          1.000000

# %%
clara_df.select_dtypes(include='number').corr()
# Out:
#                          age  duration_min  exercises_count  \
# age                      NaN           NaN              NaN
# duration_min             NaN      1.000000         0.623295
# exercises_count          NaN      0.623295         1.000000
# avg_heart_rate_bpm       NaN     -0.253095        -0.084298
# max_heart_rate_bpm       NaN     -0.248118        -0.083754
# calories_burned          NaN      0.923559         0.598236
# perceived_exertion_rpe   NaN      0.093484         0.300324
# body_weight_kg_sessions  NaN      0.061843        -0.047527
# body_fat_pct_sessions    NaN     -0.173543        -0.220065
# waist_cm_sessions        NaN      0.022251        -0.034227
# resting_heart_rate_bpm   NaN           NaN              NaN
# sleep_hours              NaN      0.025533        -0.007307
# steps                    NaN      0.011639         0.043635
# readiness_score          NaN      0.021234         0.114382
# soreness_level           NaN     -0.017074         0.059060
# ...

# %%
import seaborn as sns
sns.heatmap(clara_df.select_dtypes(include='number').corr())
# Out:
# <Axes: >
