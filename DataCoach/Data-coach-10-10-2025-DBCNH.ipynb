# %%
value = 2

# %%
if value >= 70:
    print("You are an high flier")
elif value>50 and value <70:
    print("You have sufficient knowledge")

# %%
numbers = [50, 55, 40, 75, 80, 95, 10, 34]

# %%
for numb in numbers:
    print(numb)
# Out:
# 50
# 55
# 40
# 75
# 80
# 95
# 10
# 34

# %%
for numb in numbers:
    if numb >= 70:
        print(f"the number {numb} - is an high flier")
    elif numb >=50 and numb <70:
        print(f"the number {numb} have sufficient knowledge")
    else:
        print(f"the number {numb} probably failed")
# Out:
# the number 50 have sufficient knowledge
# the number 55 have sufficient knowledge
# the number 40 probably failed
# the number 75 - is an high flier
# the number 80 - is an high flier
# the number 95 - is an high flier
# the number 10 probably failed
# the number 34 probably failed

# %%
total = 0

for numb in numbers:
    print(f"I am currently at number - {numb}")
    total = total + numb
    print(f"total now: {total}")
    
print(f"total: {total}")
# Out:
# I am currently at number - 50
# total now: 50
# I am currently at number - 55
# total now: 105
# I am currently at number - 40
# total now: 145
# I am currently at number - 75
# total now: 220
# I am currently at number - 80
# total now: 300
# I am currently at number - 95
# total now: 395
# I am currently at number - 10
# total now: 405
# I am currently at number - 34
# total now: 439
# total: 439

# %%
numbers
# Out:
# [50, 55, 40, 75, 80, 95, 10, 34]

# %%
for i in numbers:
    print(i)
# Out:
# 50
# 55
# 40
# 75
# 80
# 95
# 10
# 34

# %%
for i in numbers:
    i = i + 2
    print(i)
# Out:
# 52
# 57
# 42
# 77
# 82
# 97
# 12
# 36

# %%
numbers
# Out:
# [50, 55, 40, 75, 80, 95, 10, 34]

# %%
# [body/your output for iterator in iterable]
# [body/your output for iterator in iterable if condition]

# %%
numbers = [i+2 for i in numbers]

# %%
numbers
# Out:
# [52, 57, 42, 77, 82, 97, 12, 36]

# %%
num1 = [5, 2, 3]
num2 = [1, 3, 4]

# %%
for i in num1:
    for j in num2:
        print(f"{i}*{j}={i*j}")
# Out:
# 5*1=5
# 5*3=15
# 5*4=20
# 2*1=2
# 2*3=6
# 2*4=8
# 3*1=3
# 3*3=9
# 3*4=12

# %%
[i*j for i in num1 for j in num2]
# Out:
# [5, 15, 20, 2, 6, 8, 3, 9, 12]

# %%
set_of_fruits = {"apple", "orange", "apple", "cherry"}

# %%
for i in set_of_fruits:
    print(i)
# Out:
# orange
# apple
# cherry

# %%
set_of_fruits
# Out:
# {'apple', 'cherry', 'orange'}

# %%
{len(i) for i in set_of_fruits}
# Out:
# {5, 6}

# %%
fruit_counts = {i: len(i) for i in set_of_fruits}

# %%
i
# Out:
# 'cherry'

# %%
fruit_counts
# Out:
# {'orange': 6, 'apple': 5, 'cherry': 6}

# %%
fruit_counts["orange"]
# Out:
# 6

# %%
fruit_counts.get("cherry")
# Out:
# 6

# %%
new_fruit = "watermelon"
fruit_counts.update({new_fruit: len(new_fruit)})

# %%
fruit_counts
# Out:
# {'orange': 6, 'apple': 5, 'cherry': 6, 'watermelon': 10}

# %%
type(fruit_counts)
# Out:
# dict

# %%
# tuple/list unpacking

# %%
ages = [22, 10, 3, 5, 6]

# %%
ages[0]
# Out:
# 22

# %%
ages[-1]
# Out:
# 6

# %%
ages[1:3]
# Out:
# [10, 3]

# %%
a, b, c, d, e = ages

# %%
a
# Out:
# 22

# %%
a, *b, c = ages

# %%
a
# Out:
# 22

# %%
c
# Out:
# 6

# %%
b
# Out:
# [10, 3, 5]

# %%
fruit_counts
# Out:
# {'orange': 6, 'apple': 5, 'cherry': 6, 'watermelon': 10}

# %%
fruit_counts.items()
# Out:
# dict_items([('orange', 6), ('apple', 5), ('cherry', 6), ('watermelon', 10)])

# %%
for k, v in fruit_counts.items():
    fruit_counts[k] = fruit_counts[k] + 3

# %%
fruit_counts
# Out:
# {'orange': 9, 'apple': 8, 'cherry': 9, 'watermelon': 13}

# %%
fruit_counts["apple"] = fruit_counts["apple"] + 2
# Out:
# 10

# %%
# a python dict is a JSON in other languages
# a python dict is a glorified MongoDB
# a python dict is a glorified Pandas dataframe in Python

# %%
# a decorator is advanced

# %%
sum([2, 3, 4])
# Out:
# 9

# %%
max([9, 1, 2])
# Out:
# 9

# %%
min(1, 2, 4)
# Out:
# 1

# %%
#range(stop)
# range(start, stop)
# range(start, stop, setp)

# %%
range(5) # 0, 1, 2, 3, 4
range(2, 7) # 2, 3, 4, 5, 6
range(3, 18, 3) # 3, 6, 9, 12, 15

# %%
for i in range(2, 5):
    print(i)
# Out:
# 2
# 3
# 4

# %%
def greetings():
    print("Hello World")

# %%
greetings()
# Out:
# Hello World

# %%
def my_docator(func):
    print("about calling greetings func")
    func()
    print("done")

# %%
my_docator(greetings)
# Out:
# about calling greetings func
# Hello World
# done
