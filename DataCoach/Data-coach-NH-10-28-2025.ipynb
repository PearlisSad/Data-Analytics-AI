# %% [markdown]
# # Agenda
# - Lamda function - Samuel
# - Data process - Teresa

# %%
def add_two_numbers(x, y):
    result = x + y
    return result

# %%
add_two_numbers(3, 5)
# Out:
# 8

# %%
lambda x, y: x + y

# %%
import pandas as pd

# %%
df = pd.DataFrame(
    {
        "a": [12, 13, 5, 4, 2],
        "b": [2, 5, 9, 0, 3]
    }
)

# %%
df
# Out:
#     a  b
# 0  12  2
# 1  13  5
# 2   5  9
# 3   4  0
# 4   2  3

# %%
df.apply(lambda x: x["a"] + x["b"], axis=1)
# Out:
# 0    14
# 1    18
# 2    14
# 3     4
# 4     5
# dtype: int64

# %%
df["c"] = df.apply(lambda x: x["a"] + x["b"], axis=1)

# %%
df
# Out:
#     a  b   c
# 0  12  2  14
# 1  13  5  18
# 2   5  9  14
# 3   4  0   4
# 4   2  3   5

# %%
df["a"].apply(lambda x: x + 2)
# Out:
# 0    14
# 1    15
# 2     7
# 3     6
# 4     4
# Name: a, dtype: int64

# %%
df['a']
# Out:
# 0    12
# 1    13
# 2     5
# 3     4
# 4     2
# Name: a, dtype: int64

# %%
file = pd.ExcelFile("crimeinenglandandwalesappendixtablesyejun2025final.xlsx")

# %%
file.sheet_names
# Out:
# ['Cover Sheet',
#  'Table of contents',
#  'Notes_A1 to A4',
#  'Table_A1a',
#  'Table_A1b',
#  'Table_A2a',
#  'Table_A2b',
#  'Table_A3a',
#  'Table_A3b',
#  'Table_A4a',
#  'Table_A4b',
#  'Notes_A5 to A7',
#  'Table_A5a',
#  'Table_A5b',
#  'Summary Table_A6',
#  'Table_A7',
#  'Notes_B1 to B10',
#  'Worksheet_B1',
#  'Table_B2',
#  'Table_B3',
#  'Table_B4',
#  'Worksheet_B5',
#  'Worksheet_B6',
#  'Worksheet_B7',
#  'Table_B8',
#  'Worksheet_B9',
#  'Table_B10',
#  'Notes_C1 to C5',
#  'Table_C1',
#  'Table_C2',
#  'Table_C3',
#  'Table_C4',
#  'Table_C5',
#  'Notes_D1 to D6',
#  'Worksheet_D1',
#  'Worksheet_D2',
#  'Table_D3',
#  'Table_D4',
#  'Table_D5',
#  'Worksheet_D6',
#  'Notes_E1 to E3',
#  'Table_E1',
#  'Worksheet_E2',
#  'Table_E3']

# %%
sheet1 = pd.read_excel(file, sheet_name='Table_A1a', skiprows=7)

# %%
sheet1
# Out:
#                               Offence group\n[note 5] Jan 1981 to Dec 1981  \
# 0                                            VIOLENCE                 2063
# 1                                Violence with injury                 1226
# 2                                            Wounding                  544
# 3                           Assault with minor injury                  682
# 4                             Violence without injury                  838
# 5                                             ROBBERY                  164
# 6                             THEFT OFFENCES [note 8]                 6292
# 7                               Theft from the person                  434
# 8                            Snatch theft from person                   86
# 9                           Stealth theft from person                  258
# 10          Attempted snatch or stealth theft from...                   90
# ...

# %%
mapping = {"VIOLENCE": ["Violence with injury", 
                                 "Wounding", "Assault with minor injury", 
                                 "Violence without injury"]}

# %%
sheet1.columns
# Out:
# Index(['Offence group\n[note 5]', 'Jan 1981 to Dec 1981',
#        'Jan 1983 to Dec 1983', 'Jan 1987 to Dec 1987', 'Jan 1991 to Dec 1991',
#        'Jan 1993 to Dec 1993', 'Jan 1995 to Dec 1995', 'Jan 1997 to Dec 1997',
#        'Jan 1999 to Dec 1999', 'Apr 2001 to Mar 2002', 'Apr 2002 to Mar 2003',
#        'Apr 2003 to Mar 2004', 'Apr 2004 to Mar 2005', 'Apr 2005 to Mar 2006',
#        'Apr 2006 to Mar 2007', 'Apr 2007 to Mar 2008', 'Apr 2008 to Mar 2009',
#        'Apr 2009 to Mar 2010', 'Apr 2010 to Mar 2011', 'Apr 2011 to Mar 2012',
#        'Apr 2012 to Mar 2013\n[note 6]', 'Apr 2013 to Mar 2014',
#        'Apr 2014 to Mar 2015', 'Apr 2015 to Mar 2016', 'Apr 2016 to Mar 2017',
#        'Apr 2017 to Mar 2018', 'Apr 2018 to Mar 2019',
#        'Apr 2019 to Mar 2020\n[note 7]', 'Apr 2022 to Mar 2023',
#        'Apr 2023 to Mar 2024', 'Apr 2024 to Mar 2025', 'Jul 2023 to Jun 2024',
#        'Jul 2024 to Jun 2025'],
#       dtype='object')

# %%
sheet1.rename(columns={"Offence group\n[note 5]": "offence_group"}, inplace=True)

# %%
sheet1
# Out:
#                                         offence_group Jan 1981 to Dec 1981  \
# 0                                            VIOLENCE                 2063
# 1                                Violence with injury                 1226
# 2                                            Wounding                  544
# 3                           Assault with minor injury                  682
# 4                             Violence without injury                  838
# 5                                             ROBBERY                  164
# 6                             THEFT OFFENCES [note 8]                 6292
# 7                               Theft from the person                  434
# 8                            Snatch theft from person                   86
# 9                           Stealth theft from person                  258
# 10          Attempted snatch or stealth theft from...                   90
# ...

# %%
sheet1.query("offence_group=='VIOLENCE'")
# Out:
#   offence_group Jan 1981 to Dec 1981 Jan 1983 to Dec 1983  \
# 0      VIOLENCE                 2063                 2014
#
#   Jan 1987 to Dec 1987 Jan 1991 to Dec 1991 Jan 1993 to Dec 1993  \
# 0                 2265                 2900                 3768
#
#   Jan 1995 to Dec 1995 Jan 1997 to Dec 1997 Jan 1999 to Dec 1999  \
# 0                 4464                 3746                 3375
#
#   Apr 2001 to Mar 2002  ... Apr 2015 to Mar 2016 Apr 2016 to Mar 2017  \
# 0                 2551  ...                 1468                 1432
#
#   Apr 2017 to Mar 2018 Apr 2018 to Mar 2019 Apr 2019 to Mar 2020\n[note 7]  \
# 0                 1426                 1344                           1239
#
#   Apr 2022 to Mar 2023 Apr 2023 to Mar 2024 Apr 2024 to Mar 2025  \
# 0                  998                 1125                 1103
#
#   Jul 2023 to Jun 2024 Jul 2024 to Jun 2025
# 0                 1125                 1134
#
# [1 rows x 33 columns]

# %%
mapping["VIOLENCE"]
# Out:
# ['Violence with injury',
#  'Wounding',
#  'Assault with minor injury',
#  'Violence without injury']

# %%
sheet1
# Out:
#                                         offence_group Jan 1981 to Dec 1981  \
# 0                                            VIOLENCE                 2063
# 1                                Violence with injury                 1226
# 2                                            Wounding                  544
# 3                           Assault with minor injury                  682
# 4                             Violence without injury                  838
# 5                                             ROBBERY                  164
# 6                             THEFT OFFENCES [note 8]                 6292
# 7                               Theft from the person                  434
# 8                            Snatch theft from person                   86
# 9                           Stealth theft from person                  258
# 10          Attempted snatch or stealth theft from...                   90
# ...

# %%
sheet1["offence_group"].isin(mapping["VIOLENCE"])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# Name: offence_group, dtype: bool

# %%
sheet1["offence_group"].values
# Out:
# array(['VIOLENCE', '    Violence with injury', '        Wounding',
#        '        Assault with minor injury', '    Violence without injury',
#        'ROBBERY', 'THEFT OFFENCES [note 8]', '    Theft from the person',
#        '        Snatch theft from person',
#        '        Stealth theft from person',
#        '        Attempted snatch or stealth theft from person',
#        '    Other theft of personal property ',
#        'Unweighted base - number of people aged 16 and over',
#        '    Domestic burglary', 'With entry', '            With loss',
#        '            No loss', 'Attempts',
#        'Domestic burglary in a dwelling', '        With entry',
#        '            With loss', '            No loss', '        Attempts',
#        '    Domestic burglary in a non-connected building to a dwelling',
#        '        With entry', '            With loss',
#        '            No loss', '        Attempts',
# ...

# %%
sheet1["offence_group"] = sheet1["offence_group"].str.strip()

# %%
sheet1["offence_group"].values
# Out:
# array(['VIOLENCE', 'Violence with injury', 'Wounding',
#        'Assault with minor injury', 'Violence without injury', 'ROBBERY',
#        'THEFT OFFENCES [note 8]', 'Theft from the person',
#        'Snatch theft from person', 'Stealth theft from person',
#        'Attempted snatch or stealth theft from person',
#        'Other theft of personal property',
#        'Unweighted base - number of people aged 16 and over',
#        'Domestic burglary', 'With entry', 'With loss', 'No loss',
#        'Attempts', 'Domestic burglary in a dwelling', 'With entry',
#        'With loss', 'No loss', 'Attempts',
#        'Domestic burglary in a non-connected building to a dwelling',
#        'With entry', 'With loss', 'No loss', 'Attempts',
#        'Other household theft', 'Theft from a dwelling',
#        'Theft from outside a dwelling', 'Vehicle-related theft',
#        'Theft from vehicles', 'Theft of vehicles',
#        'Attempts of and from vehicles', 'Bicycle theft',
# ...

# %%
exp = sheet1["offence_group"].isin(mapping["VIOLENCE"])
sheet1[exp]
# Out:
#                offence_group Jan 1981 to Dec 1981 Jan 1983 to Dec 1983  \
# 1       Violence with injury                 1226                 1208
# 2                   Wounding                  544                  454
# 3  Assault with minor injury                  682                  806
# 4    Violence without injury                  838                  806
#
#   Jan 1987 to Dec 1987 Jan 1991 to Dec 1991 Jan 1993 to Dec 1993  \
# 1                 1592                 1778                 2407
# 2                  613                  791                  874
# 3                  978                  987                 1533
# 4                  674                 1122                 1360
#
#   Jan 1995 to Dec 1995 Jan 1997 to Dec 1997 Jan 1999 to Dec 1999  \
# 1                 2622                 2365                 1974
# 2                 1077                  940                  728
# 3                 1545                 1425                 1245
# ...
